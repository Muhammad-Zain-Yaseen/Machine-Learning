# %%
# !pip install deepface
# Out:
# ...
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\zaucc\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\zaucc\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\zaucc\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\zaucc\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\zaucc\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\zaucc\anaconda3\lib\site-packages)

# %%
# !pip install numpy==1.16
# Out:
# ...
#   Using cached numpy-1.16.0.zip (5.1 MB)
# ...
#   Running setup.py clean for numpy
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\zaucc\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\zaucc\anaconda3\lib\site-packages)
#   ERROR: Command errored out with exit status 1:
# ...

# %%
from deepface import DeepFace
# Out:
# C:\Users\zaucc\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
result = DeepFace.verify(
    img1_path="download (3).jpg",
    img2_path="download (2).jpg"
)

# %%
dfs = DeepFace.find(img_path = "you.jpg",
                    db_path = "C://Users/zaucc//Desktop//My AI by Corvit//Transfer Learning//Database",
                   enforce_detection=False)
#C:\Users\zaucc\Desktop\MY AI by Corvit\Transfer Learning\Database
# Out:
# WARNING: Representations for images in C://Users/zaucc//Desktop//My AI by Corvit//Transfer Learning//Database folder were previously stored in representations_vgg_face.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  13  representations found in  representations_vgg_face.pkl
# find function lasts  0.42498064041137695  seconds

# %%
embedding_objs = DeepFace.represent(img_path = "you.jpg", enforce_detection=False)

# %%
embedding = embedding_objs[0]["embedding"]
assert isinstance(embedding, list)
assert model_name = "VGG-Face" and len(embedding) == 2622
# Out:
#   Input In [7]
#     assert model_name = "VGG-Face" and len(embedding) == 2622
#                       ^
# SyntaxError: invalid syntax

# %%
models = [
  "VGG-Face", 
  "Facenet", 
  "Facenet512", 
  "OpenFace", 
  "DeepFace", 
  "DeepID", 
  "ArcFace", 
  "Dlib", 
  "SFace",
]

#face verification
result = DeepFace.verify(img1_path = "download (2).jpg", 
      img2_path = "you.jpg", 
      model_name = models[0], enforce_detection=False
)

#face recognition
dfs = DeepFace.find(img_path = "you.jpg",
      db_path = "C://Users/zaucc//Desktop//My AI by Corvit//Transfer Learning//Database", 
      model_name = models[1],enforce_detection=False
)

#embeddings
embedding_objs = DeepFace.represent(img_path = "you.jpg", 
      model_name = models[2], enforce_detection=False
                                
)
# Out:
# WARNING: Representations for images in C://Users/zaucc//Desktop//My AI by Corvit//Transfer Learning//Database folder were previously stored in representations_facenet.pkl. If you added new instances after the creation, then please delete this file and call find function again. It will create it again.
# There are  13  representations found in  representations_facenet.pkl
# find function lasts  5.615510940551758  seconds
# facenet512_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/facenet512_weights.h5
# To: C:\Users\zaucc\.deepface\weights\facenet512_weights.h5
#  23%|█████████████████▊                                                           | 22.0M/95.0M [00:18<01:00, 1.21MB/s]
